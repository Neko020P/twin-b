# %%
{
  "agent_types": {
    "student": {
      "distribution": {
        "count": 50,
        "gender_ratio": {"female": 0.6, "male": 0.4},
        "age_range": [18, 24]
      },
      "attributes": {
        "preferred_temp": {
          "distribution": "uniform",
          "min": 24,
          "max": 26
        },
        "comfort_tolerance": {
          "distribution": "uniform",
          "min": 1.5,
          "max": 2.5
        }
      },
      "behaviors": {
        "device_usage_pattern": "intermittent"
      },
      "schedule_template": "undergraduate_classes"
    },
    "staff": {
      "distribution": {
        "count": 10,
        "gender_ratio": {"female": 0.5, "male": 0.5},
        "age_range": [25, 60]
      },
      "attributes": {
        "preferred_temp": {
          "distribution": "uniform",
          "min": 25,
          "max": 27
        },
        "comfort_tolerance": {
          "distribution": "uniform",
          "min": 1,
          "max": 2
        }
      },
      "behaviors": {
        "device_usage_pattern": "work_hours"
      },
      "schedule_template": "office_hours"
    },
    "cleaner": {
      "distribution": {
        "count": 5,
        "gender_ratio": {"female": 0.4, "male": 0.6},
        "age_range": [20, 55]
      },
      "attributes": {
        "preferred_temp": {
          "distribution": "uniform",
          "min": 26,
          "max": 28
        },
        "comfort_tolerance": {
          "distribution": "uniform",
          "min": 2.5,
          "max": 3.5
        }
      },
      "behaviors": {
        "movement_pattern": "cyclic_route",
        "device_usage_pattern": "low"
      },
      "schedule_template": "cleaning_shifts"
    },
    "warden": {
      "distribution": {
        "count": 2,
        "gender_ratio": {"female": 0.5, "male": 0.5},
        "age_range": [30, 65]
      },
      "attributes": {
        "preferred_temp": {
          "distribution": "uniform",
          "min": 25,
          "max": 27
        },
        "comfort_tolerance": {
          "distribution": "uniform",
          "min": 2,
          "max": 3
        }
      },
      "behaviors": {
        "device_usage_pattern": "monitoring"
      },
      "schedule_template": "warden_duties"
    },
    "visitor": {
      "distribution": {
        "count": 20,
        "gender_ratio": {"female": 0.5, "male": 0.5},
        "age_range": [18, 65]
      },
      "attributes": {
        "preferred_temp": {
          "distribution": "uniform",
          "min": 24,
          "max": 26
        },
        "comfort_tolerance": {
          "distribution": "uniform",
          "min": 1,
          "max": 1.5
        }
      },
      "behaviors": {
        "device_usage_pattern": "short_stay"
      },
      "schedule_template": "visitor_pattern"
    },
    "policy": {
      "distribution": {
        "count": 1
      },
      "attributes": {
        "preferred_temp": {
          "fixed": 25
        },
        "max_delta": 3
      },
      "behaviors": {
        "control_action": ["heat_on", "cool_on", "hold"]
      },
      "schedule_template": "always_on"
    }
  }
}
# Out:
# {'agent_types': {'student': {'distribution': {'count': 50,
#     'gender_ratio': {'female': 0.6, 'male': 0.4},
#     'age_range': [18, 24]},
#    'attributes': {'preferred_temp': {'distribution': 'uniform',
#      'min': 24,
#      'max': 26},
#     'comfort_tolerance': {'distribution': 'uniform', 'min': 1.5, 'max': 2.5}},
#    'behaviors': {'device_usage_pattern': 'intermittent'},
#    'schedule_template': 'undergraduate_classes'},
#   'staff': {'distribution': {'count': 10,
#     'gender_ratio': {'female': 0.5, 'male': 0.5},
#     'age_range': [25, 60]},
#    'attributes': {'preferred_temp': {'distribution': 'uniform',
#      'min': 25,
#      'max': 27},
#     'comfort_tolerance': {'distribution': 'uniform', 'min': 1, 'max': 2}},
#    'behaviors': {'device_usage_pattern': 'work_hours'},
#    'schedule_template': 'office_hours'},
#   'cleaner': {'distribution': {'count': 5,
#     'gender_ratio': {'female': 0.4, 'male': 0.6},
#     'age_range': [20, 55]},
#    'attributes': {'preferred_temp': {'distribution': 'uniform',
#      'min': 26,
#      'max': 28},
#     'comfort_tolerance': {'distribution': 'uniform', 'min': 2.5, 'max': 3.5}},
#    'behaviors': {'movement_pattern': 'cyclic_route',
#     'device_usage_pattern': 'low'},
#    'schedule_template': 'cleaning_shifts'},
#   'warden': {'distribution': {'count': 2,
#     'gender_ratio': {'female': 0.5, 'male': 0.5},
#     'age_range': [30, 65]},
#    'attributes': {'preferred_temp': {'distribution': 'uniform',
#      'min': 25,
#      'max': 27},
#     'comfort_tolerance': {'distribution': 'uniform', 'min': 2, 'max': 3}},
#    'behaviors': {'device_usage_pattern': 'monitoring'},
#    'schedule_template': 'warden_duties'},
#   'visitor': {'distribution': {'count': 20,
#     'gender_ratio': {'female': 0.5, 'male': 0.5},
#     'age_range': [18, 65]},
#    'attributes': {'preferred_temp': {'distribution': 'uniform',
#      'min': 24,
#      'max': 26},
#     'comfort_tolerance': {'distribution': 'uniform', 'min': 1, 'max': 1.5}},
#    'behaviors': {'device_usage_pattern': 'short_stay'},
#    'schedule_template': 'visitor_pattern'},
#   'policy': {'distribution': {'count': 1},
#    'attributes': {'preferred_temp': {'fixed': 25}, 'max_delta': 3},
#    'behaviors': {'control_action': ['heat_on', 'cool_on', 'hold']},
#    'schedule_template': 'always_on'}}}

# %%
from mesa import Agent   
import random

class BaseAgent(Agent):
    def __init__(self, unique_id, model, zones, **kwargs):
        super().__init__(unique_id, model)
        self.agent_id = f"{self.__class__.__name__.lower()}_{unique_id}"
        self.agent_type = self.__class__.__name__.replace("Agent", "").lower()
        self.current_room = random.choice(zones) if zones else "Unknown Zone"
        self.preferred_temp = kwargs.get("preferred_temp", 25.0)
        self.comfort_tolerance = kwargs.get("comfort_tolerance", 1.0)
        self.gender = kwargs.get("gender", None)
        self.age = kwargs.get("age", None)
        self.route = kwargs.get("route", [])
        self.max_delta = kwargs.get("max_delta", 3)
        self.using_ac = False
        self.comfort_level = 0.0
        self.current_temp = None
        self.current_day = None
        self.current_hour = None

    def step(self):
        # temp = self.model.get_current_temp(self.current_room) or self.preferred_temp
        # self.current_temp = temp
        temp = self.model.get_current_temp(self.current_room)
        if temp is None:
            temp = float('nan')
        self.current_temp = temp

        self.comfort_level = max(0.0, self.preferred_temp - abs(temp - self.preferred_temp))
        self.using_ac = abs(temp - self.preferred_temp) > self.comfort_tolerance

        self.current_day = getattr(self.model, "current_day", None)
        self.current_hour = getattr(self.model, "current_hour", None)

        self.model.agent_results.append({
            "day": self.current_day,
            "hour": self.current_hour,
            "step": self.model.current_step,
            "agent_id": self.agent_id,
            "agent_type": self.agent_type,
            "room": self.current_room,
            "current_temp": self.current_temp,
            "comfort_level": round(self.comfort_level, 2),
            "using_ac": self.using_ac,
            "preferred_temp": self.preferred_temp
        })

class StudentAgent(BaseAgent): pass
class StaffAgent(BaseAgent): pass
class CleanerAgent(BaseAgent): pass
class WardenAgent(BaseAgent): pass
class VisitorAgent(BaseAgent): pass
class PolicyAgent(BaseAgent): pass

# %%
# utils.py
import random
import json

def sample_value(attr_cfg):
    if attr_cfg is None:
        return None

    dist = attr_cfg.get("distribution")
    if dist == "uniform":
        return random.uniform(attr_cfg["min"], attr_cfg["max"])
    if dist == "normal":
        return random.gauss(attr_cfg["mean"], attr_cfg["std_dev"])
    if "fixed" in attr_cfg:
        return attr_cfg["fixed"]
    if "value" in attr_cfg:
        return attr_cfg["value"]
    if "min" in attr_cfg and "max" in attr_cfg:
        return random.uniform(attr_cfg["min"], attr_cfg["max"])
    return None

def sample_gender(gender_ratio):
    """gender_ratio: {'female':0.6,'male':0.4}"""
    if not gender_ratio:
        return None
    choices = list(gender_ratio.keys())
    weights = list(gender_ratio.values())
    return random.choices(choices, weights=weights, k=1)[0]

def sample_age(age_range):
    if not age_range:
        return None
    return random.randint(age_range[0], age_range[1])

def sample_agent_attributes(agent_type, agents_file="agents.json"):
    with open(agents_file, "r") as f:
        data = json.load(f)

    agent_info = data["agent_types"].get(agent_type)
    if not agent_info:
        raise ValueError(f"Agent type '{agent_type}' not found in {agents_file}")

    attrs = {}

    # attributes
    for attr_name, cfg in agent_info.get("attributes", {}).items():
        attrs[attr_name] = sample_value(cfg)

    dist_cfg = agent_info.get("distribution", {})
    attrs["gender"] = sample_gender(dist_cfg.get("gender_ratio"))
    attrs["age"] = sample_age(dist_cfg.get("age_range"))

    return attrs

# %%
import sys
sys.path.append("/project/lt200291-ignite/Project_chomwong/energyplus/EnergyPlus-25.1.0-1c11a3d85f-Linux-CentOS7.9.2009-x86_64")  # ตัวอย่าง path, ตรวจสอบจริงด้วย `module show energyplus`
from pyenergyplus.api import EnergyPlusAPI

import os
import json
import random
import pandas as pd
from mesa import Model
from mesa.time import RandomActivation
from mesa.datacollection import DataCollector

from agent import StudentAgent, StaffAgent, CleanerAgent, WardenAgent, VisitorAgent, PolicyAgent
from utils import sample_value, sample_gender, sample_age

from eppy.modeleditor import IDF


class BuildingModel(Model):
    def __init__(self, config, agents_file=None, idf_path=None, ep_control=False):
        super().__init__()
        self.schedule = RandomActivation(self)
        self.config = config
        self.current_step = 0
        self.ep_control = ep_control
        self.zones = config["mesa"].get("zones", [])
        self.last_zone_temps = {z: None for z in self.zones}
        self.agent_results = []

        self.current_day = None
        self.current_hour = None

        # ----------------- DataCollector -----------------
        self.datacollector = DataCollector(
            model_reporters={
                f"AvgTemp_{zone.replace(' ', '_')}": (lambda m, z=zone: m.get_current_temp(z))
                for zone in self.zones
            }
        )

        # ----------------- JSON (agents) -----------------
        if agents_file and os.path.exists(agents_file):
            with open(agents_file, "r") as f:
                self.agent_config = json.load(f)
            self._create_agents_from_json()
        else:
            print("[WARN] agents_file ไม่พบหรือไม่ระบุ → จะไม่มี agent ถูกสร้าง")

        # ----------------- EnergyPlus Setup -----------------
        if self.ep_control:
            idf_zone_names = []
            if idf_path:
                try:
                    idd_path = "/project/lt200291-ignite/Project_chomwong/energyplus/EnergyPlus-25.1.0-1c11a3d85f-Linux-CentOS7.9.2009-x86_64/Energy+.idd"
                    IDF.setiddname(idd_path)
                    idf = IDF(idf_path)
                    idf_zone_names = [z.Name for z in idf.idfobjects.get('ZONE', [])]
                except Exception as e:
                    print(f"[WARN] ไม่สามารถโหลด IDF: {e}")
                    idf_zone_names = []

            self.api = EnergyPlusAPI()
            self.state = self.api.state_manager.new_state()
            self.exchange = self.api.exchange

            def normalize(name):
                return name.lower().strip().replace(" ", "_")

            norm_idf_zones = {normalize(z): z for z in idf_zone_names}
            self.zone_name_map = {z: norm_idf_zones.get(normalize(z), None) for z in self.zones}
            print("Zone map:", self.zone_name_map)

            self.zone_temp_handles = {}
            self.zone_setpoint_handles = {}

            def setup_handles_first_timestep(state):
                for zone in self.zones:
                    ep_zone = self.zone_name_map.get(zone)
                    if ep_zone is None:
                        print(f"[WARN] ไม่มี mapping ระหว่าง zone '{zone}' กับ IDF zone names")
                        continue

                    temp_handle = self.exchange.get_variable_handle(state, "Zone Air Temperature", ep_zone)
                    if temp_handle == -1:
                        print(f"[WARN] ไม่พบ variable 'Zone Air Temperature' ของ zone '{zone}' (ep zone: {ep_zone})")

                    sp_handle = self.exchange.get_actuator_handle(state, "Zone Temperature Control", "Cooling Setpoint", ep_zone)
                    if sp_handle == -1:
                        print(f"[WARN] ไม่พบ actuator 'Cooling Setpoints' ของ zone '{zone}' (ep zone: {ep_zone})")

                    self.zone_temp_handles[zone] = temp_handle
                    self.zone_setpoint_handles[zone] = sp_handle

                print("Zone temp handles:", self.zone_temp_handles)
                print("Zone setpoint handles:", self.zone_setpoint_handles)

            self.api.runtime.callback_after_predictor_after_hvac_managers(
                self.state, setup_handles_first_timestep
            )

    # ============================================================
    # agents creation
    # ============================================================
    def _create_agents_from_json(self):
        mapping = {
            "student": StudentAgent,
            "staff": StaffAgent,
            "cleaner": CleanerAgent,
            "warden": WardenAgent,
            "visitor": VisitorAgent,
            "policy": PolicyAgent
        }

        total_created = 0
        for agent_type, info in self.agent_config.get("agent_types", {}).items():
            dist = info.get("distribution", {})
            count = dist.get("count", 1)

            for i in range(count):
                preferred_temp_attr = info.get("attributes", {}).get("preferred_temp", {"distribution": "uniform", "min": 25, "max": 25})
                comfort_tolerance_attr = info.get("attributes", {}).get("comfort_tolerance", {"distribution": "uniform", "min": 1, "max": 1})

                preferred_temp = sample_value(preferred_temp_attr)
                comfort_tolerance = sample_value(comfort_tolerance_attr)

                room = random.choice(self.zones) if self.zones else "Unknown Zone"

                AgentClass = mapping.get(agent_type, StudentAgent)
                agent = AgentClass(
                    unique_id=f"{agent_type}_{i}",
                    model=self,
                    zones=self.zones,
                    current_room=room,
                    preferred_temp=preferred_temp,
                    comfort_tolerance=comfort_tolerance,
                    agent_type=agent_type
                )
                self.schedule.add(agent)
                total_created += 1

        print(f"✅ โหลด agent สำเร็จทั้งหมด: {total_created} ตัว")


    # ============================================================
    #  EP-control methods
    # ============================================================
    def get_current_temp(self, zone_name):
        return self.last_zone_temps.get(zone_name)

    def compute_setpoint_requests(self):
        requests = {}
        per_zone = {}
        for agent in self.schedule.agents:
            if getattr(agent, "using_ac", False) and agent.current_room:
                per_zone.setdefault(agent.current_room, []).append(agent.preferred_temp)
        for zone, temps in per_zone.items():
            temps = [t for t in temps if t is not None]
            if temps:
                requests[zone] = min(temps)
        return requests

    def read_zone_temps_from_ep(self):
        temps = {}
        for zone in self.zones:
            handle = self.zone_temp_handles.get(zone, -1)
            if handle in [None, -1]:
                temps[zone] = None
            else:
                try:
                    temps[zone] = self.exchange.get_variable_value(self.state, handle)
                except Exception:
                    temps[zone] = None
        return temps

    def apply_setpoints_to_ep(self, setpoint_map: dict):
        for zone, val in (setpoint_map or {}).items():
            handle = self.zone_setpoint_handles.get(zone, -1)
            if handle in [None, -1]:
                continue
            try:
                self.exchange.set_actuator_value(self.state, handle, val)
            except Exception:
                continue

    # ============================================================
    #  Agent step logic
    # ============================================================
    def step_agents(self, ep_model=None):
        if ep_model is not None:
            zone_temps = ep_model.read_zone_temps_from_ep()
            for z, t in zone_temps.items():
                if t is not None:
                    self.last_zone_temps[z] = t

        for agent in self.schedule.agents:
            temp = self.last_zone_temps.get(agent.current_room)
            agent.current_temp = temp

            if temp is not None:
                try:
                    agent.comfort_level = max(0.0, agent.preferred_temp - abs(temp - agent.preferred_temp))
                except Exception:
                    agent.comfort_level = None

                agent.using_ac = abs(temp - agent.preferred_temp) > agent.comfort_tolerance
            else:
                agent.comfort_level = None
                agent.using_ac = False

            agent.current_day = getattr(self, "current_day", None)
            agent.current_hour = getattr(self, "current_hour", None)

            self.agent_results.append({
                "day": agent.current_day,
                "hour": agent.current_hour,
                "step": self.current_step,
                "agent_id": agent.unique_id,
                "agent_type": agent.agent_type,
                "room": agent.current_room,
                "current_temp": agent.current_temp,
                "comfort_level": round(agent.comfort_level, 2) if agent.comfort_level is not None else None,
                "using_ac": agent.using_ac,
                "preferred_temp": agent.preferred_temp
            })

        try:
            self.datacollector.collect(self)
        except Exception:
            pass

        self.current_step += 1

    def collect_agent_results(self):
        return getattr(self, "agent_results", [])

    # ============================================================
    #  Export results
    # ============================================================
    def export_zone_csv(self, filename="zone_results.csv"):
        df = self.datacollector.get_model_vars_dataframe()
        df.to_csv(filename)
        print(f"Zone-level results saved to {filename}")

    def export_agent_csv(self, filename="agent_results.csv"):
        df = pd.DataFrame(self.agent_results)
        df.to_csv(filename, index=False)
        print(f"Agent-level results saved to {filename}")

    # # ============================================================
    # #  Quick run + export
    # # ============================================================
    # def run_simulation_and_export(self, steps, zone_file="zone_results.csv", agent_file="agent_results.csv"):
    #     for _ in range(steps):
    #         self.step_agents(ep_model=self if self.ep_control else None)
    #     self.export_zone_csv(zone_file)
    #     self.export_agent_csv(agent_file)

# %%
import os
os.environ["ENERGYPLUS_EXE"] = "/project/lt200291-ignite/Project_chomwong/energyplus/EnergyPlus-25.1.0-1c11a3d85f-Linux-CentOS7.9.2009-2023-x86_64/energyplus"
os.environ["NCCL_DEBUG"] = "INFO"
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["TORCH_NCCL_TIMEOUT"] = "1200"
os.environ["TORCH_DISTRIBUTED_DEBUG"] = "DETAIL"

import yaml
import json
import pandas as pd
import torch
import torch.distributed as dist
import queue
import threading
from model import BuildingModel

def init_distributed():
    rank = int(os.environ.get("RANK", 0))
    world_size = int(os.environ.get("WORLD_SIZE", 1))
    gpu_count = torch.cuda.device_count()

    if world_size > 1:
        backend = "nccl" if torch.cuda.is_available() and rank < gpu_count else "gloo"
        dist.init_process_group(
            backend=backend,
            rank=rank,
            world_size=world_size,
            init_method="env://"
        )
    else:
        backend = "gloo"

    device = torch.device(f"cuda:{rank}") if backend == "nccl" else torch.device("cpu")
    if backend == "nccl":
        torch.cuda.set_device(device)
    print(f"[Rank {rank}] Using backend={backend}, device={device}", flush=True)
    return rank, world_size, device, backend

def dict_to_tensor(d, keys, device):
    return torch.tensor([d.get(k, float('inf')) for k in keys], dtype=torch.float32, device=device)

def tensor_to_dict(tensor, keys):
    return {k: float(v) for k, v in zip(keys, tensor.tolist())}

def run_simulation():
    with open("config.yaml", "r") as f:
        config = yaml.safe_load(f)
    with open("agents.json", "r") as f:
        agents_json = json.load(f)

    rank, world_size, device, backend = init_distributed()
    steps = config["mesa"]["steps"]
    zone_keys = config["mesa"]["zones"]
    print("Zones:", zone_keys, flush=True)

    callback_queue = queue.Queue()

    model_agents = BuildingModel(config, "agents.json", ep_control=False)

    ep_model = None
    if rank == 0:
        idf_path = "/project/lt200291-ignite/Project_chomwong/project/EnergyPlus_BP_Boonchoo/2ZoneDataCenterHVAC_wEconomizer.idf"
        weather_path = "/project/lt200291-ignite/Project_chomwong/project/EnergyPlus_BP_Boonchoo/DEU_BW_Stuttgart.AP.107380_TMYx.2009-2023.epw"
        ep_model = BuildingModel(config, ep_control=True, idf_path=idf_path)
        os.makedirs("outEnergyPlus", exist_ok=True)

        def ep_agent_callback(state):
            print("[Callback] Triggered", flush=True)

            zone_temps = ep_model.read_zone_temps_from_ep()
            print("Current zone temperatures in EP:", flush=True)
            for zone, temp in zone_temps.items():
                print(f"  {zone}: {temp if temp is not None else 'N/A'}", flush=True)
            
            ep_model.last_zone_temps.update(zone_temps)
            
            callback_queue.put(zone_temps)
            
            local_requests = ep_model.compute_setpoint_requests()
            ep_model.apply_setpoints_to_ep(local_requests)

        ep_model.api.runtime.callback_after_predictor_after_hvac_managers(
            ep_model.state, ep_agent_callback
        )

        ep_args = ["-d", "./outEnergyPlus", "-w", weather_path, idf_path]
        ep_thread = threading.Thread(target=lambda: ep_model.api.runtime.run_energyplus(ep_model.state, ep_args))
        ep_thread.start()
    else:
        ep_thread = None

    for step in range(steps):
        if rank == 0:
            zone_temps = callback_queue.get()
            model_agents.last_zone_temps.update(zone_temps)
    
            model_agents.step_agents(ep_model=None)
    
            for agent in model_agents.schedule.agents:
                print(f"{agent.unique_id}: current_temp={agent.current_temp}, wants={agent.preferred_temp}, using_ac={agent.using_ac}", flush=True)
    
        local_requests = model_agents.compute_setpoint_requests() if rank == 0 else {k: float('inf') for k in zone_keys}
        local_tensor = dict_to_tensor(local_requests, zone_keys, device)
    
        if world_size > 1:
            gathered = [torch.zeros_like(local_tensor) for _ in range(world_size)]
            dist.all_gather(gathered, local_tensor)
            merged_tensor = torch.min(torch.stack(gathered), dim=0).values
        else:
            merged_tensor = local_tensor
    
        merged_dict = tensor_to_dict(merged_tensor, zone_keys)
    
        if rank == 0 and ep_model:
            ep_model.apply_setpoints_to_ep(merged_dict)
            print("Applied setpoints to EP:", flush=True)
            for z, val in merged_dict.items():
                print(f"  {z}: {val:.2f} °C", flush=True)
    
        if (step + 1) % max(1, steps // 5) == 0:
            print(f"[Rank {rank}] Step {step+1}/{steps}", flush=True)
    
        if world_size > 1:
            dist.barrier()

    if rank == 0 and ep_thread:
        ep_thread.join()

    local_results = model_agents.collect_agent_results()
    if world_size > 1:
        dist.barrier()
        gathered_results = [None] * world_size
        dist.all_gather_object(gathered_results, local_results)
        if rank == 0:
            combined = []
            for sub in gathered_results:
                if sub:
                    combined.extend(sub)
            df = pd.DataFrame(combined)
            df.to_csv("mesa_agent_results.csv", index=False)
            print("[Rank 0] Results saved.", flush=True)
        dist.destroy_process_group()
    else:
        df = pd.DataFrame(local_results)
        df.to_csv("mesa_agent_results.csv", index=False)
        print("[Single rank] Results saved.", flush=True)

if __name__ == "__main__":
    run_simulation()
# Out:
# [Rank 0] Using backend=gloo, device=cpu
# Zones: ['West Zone', 'East Zone']
# ✅ โหลด agent สำเร็จทั้งหมด: 88 ตัว
# [WARN] agents_file ไม่พบหรือไม่ระบุ → จะไม่มี agent ถูกสร้าง
# Zone map: {'West Zone': 'West Zone', 'East Zone': 'East Zone'}
# EnergyPlus Starting
# EnergyPlus, Version 25.1.0-1c11a3d85f, YMD=2025.10.13 22:08
# Initializing Response Factors
# Calculating CTFs for "EXT-WALLS"
# Calculating CTFs for "FLOOR"
# Calculating CTFs for "PARTITION"
# Calculating CTFs for "PLENUM FLOOR"
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Computing Interior Solar Absorption Factors
# Determining Shadowing Combinations
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Setting up Surface Reporting Variables
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Initializing HVAC
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #1 CHICAGO_IL_USA ANNUAL HEATING 99% DESIGN CONDITIONS DB
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #2 CHICAGO_IL_USA ANNUAL COOLING 1% DESIGN CONDITIONS DB/MCWB
# Calculating System sizing
# ...for Sizing Period: #1 CHICAGO_IL_USA ANNUAL HEATING 99% DESIGN CONDITIONS DB
# Calculating System sizing
# ...for Sizing Period: #2 CHICAGO_IL_USA ANNUAL COOLING 1% DESIGN CONDITIONS DB/MCWB
# Adjusting Air System Sizing
# Adjusting Standard 62.1 Ventilation Sizing
# Initializing Simulation
# Reporting Surfaces
# Beginning Primary Simulation
# Initializing New Environment Parameters
# Warming up {1}
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.0
#   East Zone: 23.0
# student_0: current_temp=23.0, wants=24.675240423840595, using_ac=False
# Zone temp handles:student_1: current_temp=23.0, wants=25.858929169130345, using_ac=True
# student_2: current_temp=23.0, wants=24.413816872458025, using_ac=False
#  {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_3: current_temp=23.0, wants=24.735525892064874, using_ac=True
# student_4: current_temp=23.0, wants=24.952141524063997, using_ac=False
# Current zone temperatures in EP:
# student_5: current_temp=23.0, wants=24.617357321504233, using_ac=False
#   West Zone: 21.39922323906939
# student_6: current_temp=23.0, wants=25.670119139586646, using_ac=True
# student_7: current_temp=23.0, wants=24.01790091811912, using_ac=False
#   East Zone: 20.33514954689939
# student_8: current_temp=23.0, wants=24.07530597762634, using_ac=False
# student_9: current_temp=23.0, wants=24.095973720210257, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_10: current_temp=23.0, wants=25.53965501264419, using_ac=True
# student_11: current_temp=23.0, wants=25.616388794601523, using_ac=True
# Current zone temperatures in EP:
#   West Zone: 22.996341768736546
# student_12: current_temp=23.0, wants=25.66849558644953, using_ac=True
#   East Zone: 22.997740002168275
# student_13: current_temp=23.0, wants=24.031225836254226, using_ac=False
# student_14: current_temp=23.0, wants=25.09637354045358, using_ac=True
# student_15: current_temp=23.0, wants=25.31861401359614, using_ac=True
# student_16: current_temp=23.0, wants=25.304138998971148, using_ac=True
# student_17: current_temp=23.0, wants=24.59862081577627, using_ac=False
# student_18: current_temp=23.0, wants=25.930887908384154, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_19: current_temp=23.0, wants=25.142757419205235, using_ac=False
# Current zone temperatures in EP:
#   West Zone: 22.992167344417737
# student_20: current_temp=23.0, wants=25.73104887698365, using_ac=True
# student_21: current_temp=23.0, wants=25.525578459697634, using_ac=True
#   East Zone: 23.136611531109388
# student_22: current_temp=23.0, wants=25.93841346869749, using_ac=True
# student_23: current_temp=23.0, wants=24.150402060556274, using_ac=False
# student_24: current_temp=23.0, wants=25.7133169721554, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
# student_25: current_temp=23.0, wants=24.08356296836369, using_ac=False
#   West Zone: 22.992106999830508
# student_26: current_temp=23.0, wants=25.71790006107961, using_ac=True
#   East Zone: 23.292564544425964
# student_27: current_temp=23.0, wants=25.29973726369989, using_ac=False
# student_28: current_temp=23.0, wants=25.320341714726393, using_ac=True
# student_29: current_temp=23.0, wants=25.395950822014726, using_ac=True
# student_30: current_temp=23.0, wants=24.010069677661022, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_31: current_temp=23.0, wants=24.330557206510434, using_ac=False
# Current zone temperatures in EP:
# student_32: current_temp=23.0, wants=24.044175332068328, using_ac=False
#   West Zone: 22.998244129660357
# student_33: current_temp=23.0, wants=25.185805046438368, using_ac=False
# student_34: current_temp=23.0, wants=24.792734658096002, using_ac=False
#   East Zone: 23.4153536484115
# student_35: current_temp=23.0, wants=24.12056442608282, using_ac=False
# student_36: current_temp=23.0, wants=24.67487502913001, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_37: current_temp=23.0, wants=25.838426161570183, using_ac=True
# Current zone temperatures in EP:
# student_38: current_temp=23.0, wants=24.738612438246435, using_ac=False
#   West Zone: 23.00729881202341
# student_39: current_temp=23.0, wants=25.138477774114477, using_ac=False
#   East Zone: 23.5399226007521
# student_40: current_temp=23.0, wants=24.56316143565178, using_ac=False
# student_41: current_temp=23.0, wants=25.274085019728115, using_ac=True
# student_42: current_temp=23.0, wants=25.299339943223057, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_43: current_temp=23.0, wants=25.70075881254443, using_ac=True
# student_44: current_temp=23.0, wants=25.383046075684923, using_ac=True
# Current zone temperatures in EP:
#   West Zone: 23.01168056951602
# student_45: current_temp=23.0, wants=24.358484458304993, using_ac=False
# student_46: current_temp=23.0, wants=25.72634461684155, using_ac=True
#   East Zone: 23.671077179128122
# student_47: current_temp=23.0, wants=25.093274849662848, using_ac=True
# student_48: current_temp=23.0, wants=24.149846586813176, using_ac=False
# student_49: current_temp=23.0, wants=25.58430520108372, using_ac=True
# staff_0: current_temp=23.0, wants=26.60661847659038, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
# staff_1: current_temp=23.0, wants=26.645490031816188, using_ac=True
#   West Zone: 23.00218709813049
# staff_2: current_temp=23.0, wants=26.75848176823084, using_ac=True
#   East Zone: 23.799865885151338
# staff_3: current_temp=23.0, wants=25.517438461166538, using_ac=True
# staff_4: current_temp=23.0, wants=26.500497257272873, using_ac=True
# staff_5: current_temp=23.0, wants=25.77593567044644, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# staff_6: current_temp=23.0, wants=25.425027965873138, using_ac=True
# staff_7: current_temp=23.0, wants=26.469932585323726, using_ac=True
# Current zone temperatures in EP:
# staff_8: current_temp=23.0, wants=25.090242248851805, using_ac=True
#   West Zone: 22.980041030957473
#   East Zone: 23.92723824515164
# staff_9: current_temp=23.0, wants=25.275919252333562, using_ac=True
# cleaner_0: current_temp=23.0, wants=27.24913785097528, using_ac=True
# cleaner_1: current_temp=23.0, wants=27.69715369668513, using_ac=True
# cleaner_2: current_temp=23.0, wants=27.363008467340865, using_ac=True
# Zone temp handles:cleaner_3: current_temp=23.0, wants=27.88613437280151, using_ac=True
#  {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# cleaner_4: current_temp=23.0, wants=27.774420392923584, using_ac=True
# Current zone temperatures in EP:
#   West Zone: 22.964083502549634
# warden_0: current_temp=23.0, wants=26.619725591690457, using_ac=True
# warden_1: current_temp=23.0, wants=25.0066133093452, using_ac=False
#   East Zone: 24.055068861720944
# visitor_0: current_temp=23.0, wants=24.249268117344005, using_ac=False
# visitor_1: current_temp=23.0, wants=24.359206341372037, using_ac=True
# Zone temp handles:visitor_2: current_temp=23.0, wants=24.02663712975208, using_ac=False
# visitor_3: current_temp=23.0, wants=25.314272454215118, using_ac=True
#  {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
# visitor_4: current_temp=23.0, wants=24.03119252642477, using_ac=False
# visitor_5: current_temp=23.0, wants=25.659053595698662, using_ac=True
#   West Zone: 22.974820143495275
# visitor_6: current_temp=23.0, wants=25.181083868355653, using_ac=True
#   East Zone: 24.182690723823566
# visitor_7: current_temp=23.0, wants=24.73330685774162, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# visitor_8: current_temp=23.0, wants=24.401414514438766, using_ac=True
# Current zone temperatures in EP:
# visitor_9: current_temp=23.0, wants=25.672447656316677, using_ac=True
#   West Zone: 33.43570812885471
#   East Zone: 27.661609914253763
# visitor_10: current_temp=23.0, wants=24.917866901328225, using_ac=True
# visitor_11: current_temp=23.0, wants=24.96635696585956, using_ac=True
# visitor_12: current_temp=23.0, wants=24.86885891391655, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# visitor_13: current_temp=23.0, wants=24.391652805428798, using_ac=True
# Current zone temperatures in EP:
# visitor_14: current_temp=23.0, wants=24.968375078730734, using_ac=True
#   West Zone: 24.595657996039918
# visitor_15: current_temp=23.0, wants=25.09521667227684, using_ac=True
#   East Zone: 25.054563838277815
# visitor_16: current_temp=23.0, wants=24.019622798236405, using_ac=False
# visitor_17: current_temp=23.0, wants=24.58388467486708, using_ac=True
# visitor_18: current_temp=23.0, wants=24.239016345168007, using_ac=True
# visitor_19: current_temp=23.0, wants=24.21310866824882, using_ac=False
# policy_0: current_temp=23.0, wants=25, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 25.302228270118373
#   East Zone: 26.57154786121202
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.33017284691115
#   East Zone: 27.796486015448167
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 22.08154103957073
#   East Zone: 28.97636031866053
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 22.438926357167155
#   East Zone: 30.170635881165616
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.324549051977137
#   East Zone: 31.32191767101836
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.047509775788686
#   East Zone: 32.42462381240908
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.004191697315544
#   East Zone: 33.214885627447885
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.001123334841026
#   East Zone: 33.56553959646649
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.000585914551454
#   East Zone: 33.693360585303196
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.000517740647513
#   East Zone: 33.708545459339476
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.00061733815541
#   East Zone: 33.65526619866309
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.00063075297774
#   East Zone: 33.58829644653728
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.000525318656454
#   East Zone: 33.57054882724092
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.000397143324328
#   East Zone: 33.60117977321682
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 21.661577180187166
#   East Zone: 34.695855427546206
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 22.58823904029962
#   East Zone: 33.65016578164505
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 22.33302190072231
#   East Zone: 34.37029835998125
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 22.550803739233537
#   East Zone: 35.76253220067732
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.038368650664797
#   East Zone: 37.16151489662459
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.288935228959527
#   East Zone: 38.33882429426857
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.109213893602313
#   East Zone: 39.25282991113012
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.010819179535964
#   East Zone: 39.59013394338004
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.001505439508566
#   East Zone: 39.40431803028319
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.00022931404917
#   East Zone: 39.20742214353286
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.000057823588186
#   East Zone: 39.32698649875645
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.000032997587674
#   East Zone: 39.56197948413562
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.000027880711745
#   East Zone: 39.579729135543396
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.000025580881466
#   East Zone: 39.39931232421808
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.0000238812166
#   East Zone: 39.302000423934665
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.00002244053101
#   East Zone: 39.403020303120414
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 25.85843960549203
#   East Zone: 40.37112474687557
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.701301750952254
#   East Zone: 39.33774582612734
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 24.266847413119294
#   East Zone: 41.10316616317056
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.714193898478293
#   East Zone: 42.796628599743734
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.107506242141387
#   East Zone: 43.86325251020349
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.017158429409506
#   East Zone: 44.14649888778186
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.00337592772395
#   East Zone: 44.12881589004851
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.00065287287388
#   East Zone: 44.25503647031365
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.00017862595245
#   East Zone: 44.451573228962445
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.000080157215496
#   East Zone: 44.48571519847019
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.000052041222766
#   East Zone: 44.397178020924976
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.000039753914358
#   East Zone: 44.37142060444502
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.00009038941094
#   East Zone: 45.21712431773146
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.030761816993255
#   East Zone: 44.75457152556282
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.004888661051385
#   East Zone: 46.33163672261994
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.00069877520356
#   East Zone: 47.947683572407676
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.000137822922454
#   East Zone: 48.27160006021659
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 23.000042904955492
#   East Zone: 47.84445943244339
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
# Applied setpoints to EP:
#   West Zone: 23.000026412262148  West Zone: 24.40 °C
#
#   East Zone: 47.818064055400924
#   East Zone: 24.24 °C
# student_0: current_temp=21.39922323906939, wants=24.675240423840595, using_ac=True
# student_1: current_temp=20.33514954689939, wants=25.858929169130345, using_ac=True
# student_2: current_temp=21.39922323906939, wants=24.413816872458025, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_3: current_temp=20.33514954689939, wants=24.735525892064874, using_ac=True
# Current zone temperatures in EP:
# student_4: current_temp=20.33514954689939, wants=24.952141524063997, using_ac=True
#   West Zone: 23.00002434918942
# student_5: current_temp=20.33514954689939, wants=24.617357321504233, using_ac=True
#   East Zone: 48.22749243903066
# student_6: current_temp=21.39922323906939, wants=25.670119139586646, using_ac=True
# student_7: current_temp=20.33514954689939, wants=24.01790091811912, using_ac=True
# student_8: current_temp=21.39922323906939, wants=24.07530597762634, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_9: current_temp=21.39922323906939, wants=24.095973720210257, using_ac=True
# Current zone temperatures in EP:
# student_10: current_temp=20.33514954689939, wants=25.53965501264419, using_ac=True
#   West Zone: 23.0000227767274
# student_11: current_temp=20.33514954689939, wants=25.616388794601523, using_ac=True
#   East Zone: 48.393997631802634
# student_12: current_temp=21.39922323906939, wants=25.66849558644953, using_ac=True
# student_13: current_temp=20.33514954689939, wants=24.031225836254226, using_ac=True
# student_14: current_temp=20.33514954689939, wants=25.09637354045358, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
# student_15: current_temp=21.39922323906939, wants=25.31861401359614, using_ac=True
#   West Zone: 23.000020208610756
#   East Zone: 48.18679793524955
# student_16: current_temp=20.33514954689939, wants=25.304138998971148, using_ac=True
# student_17: current_temp=21.39922323906939, wants=24.59862081577627, using_ac=True
# student_18: current_temp=21.39922323906939, wants=25.930887908384154, using_ac=True
# student_19: current_temp=20.33514954689939, wants=25.142757419205235, using_ac=True
# student_20: current_temp=21.39922323906939, wants=25.73104887698365, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_21: current_temp=20.33514954689939, wants=25.525578459697634, using_ac=True
# Current zone temperatures in EP:
# student_22: current_temp=20.33514954689939, wants=25.93841346869749, using_ac=True
#   West Zone: 23.000017914591734
#   East Zone: 48.04615756459343
# student_23: current_temp=21.39922323906939, wants=24.150402060556274, using_ac=True
# student_24: current_temp=20.33514954689939, wants=25.7133169721554, using_ac=True
# student_25: current_temp=21.39922323906939, wants=24.08356296836369, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_26: current_temp=20.33514954689939, wants=25.71790006107961, using_ac=True
# Current zone temperatures in EP:
#   West Zone: 23.0000163133196
# student_27: current_temp=21.39922323906939, wants=25.29973726369989, using_ac=True
#   East Zone: 48.16017124831262
# student_28: current_temp=21.39922323906939, wants=25.320341714726393, using_ac=True
# student_29: current_temp=20.33514954689939, wants=25.395950822014726, using_ac=True
# student_30: current_temp=21.39922323906939, wants=24.010069677661022, using_ac=True
# Zone temp handles:student_31: current_temp=20.33514954689939, wants=24.330557206510434, using_ac=True
#  {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_32: current_temp=20.33514954689939, wants=24.044175332068328, using_ac=True
# Current zone temperatures in EP:
# student_33: current_temp=20.33514954689939, wants=25.185805046438368, using_ac=True
#   West Zone: 23.985461776700443
# student_34: current_temp=21.39922323906939, wants=24.792734658096002, using_ac=True
#   East Zone: 48.91235647183617
# student_35: current_temp=20.33514954689939, wants=24.12056442608282, using_ac=True
# student_36: current_temp=20.33514954689939, wants=24.67487502913001, using_ac=True
# student_37: current_temp=21.39922323906939, wants=25.838426161570183, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_38: current_temp=20.33514954689939, wants=24.738612438246435, using_ac=True
# student_39: current_temp=21.39922323906939, wants=25.138477774114477, using_ac=True
# Current zone temperatures in EP:
# student_40: current_temp=21.39922323906939, wants=24.56316143565178, using_ac=True
#   West Zone: 24.0582495688099
# student_41: current_temp=21.39922323906939, wants=25.274085019728115, using_ac=True
#   East Zone: 48.731657977223726
# student_42: current_temp=20.33514954689939, wants=25.299339943223057, using_ac=True
# student_43: current_temp=21.39922323906939, wants=25.70075881254443, using_ac=True
# student_44: current_temp=21.39922323906939, wants=25.383046075684923, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_45: current_temp=20.33514954689939, wants=24.358484458304993, using_ac=True
# Current zone temperatures in EP:
# student_46: current_temp=20.33514954689939, wants=25.72634461684155, using_ac=True
#   West Zone: 24.85466325561739
# student_47: current_temp=20.33514954689939, wants=25.093274849662848, using_ac=True
# student_48: current_temp=20.33514954689939, wants=24.149846586813176, using_ac=True
#   East Zone: 49.39611499724218
# student_49: current_temp=21.39922323906939, wants=25.58430520108372, using_ac=True
# staff_0: current_temp=20.33514954689939, wants=26.60661847659038, using_ac=True
# staff_1: current_temp=21.39922323906939, wants=26.645490031816188, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# staff_2: current_temp=20.33514954689939, wants=26.75848176823084, using_ac=True
# Current zone temperatures in EP:
#   West Zone: 24.530779383908698
# staff_3: current_temp=20.33514954689939, wants=25.517438461166538, using_ac=True
# staff_4: current_temp=20.33514954689939, wants=26.500497257272873, using_ac=True
#   East Zone: 49.58679221243413
# staff_5: current_temp=21.39922323906939, wants=25.77593567044644, using_ac=True
# staff_6: current_temp=20.33514954689939, wants=25.425027965873138, using_ac=True
# staff_7: current_temp=21.39922323906939, wants=26.469932585323726, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# staff_8: current_temp=21.39922323906939, wants=25.090242248851805, using_ac=True
# staff_9: current_temp=20.33514954689939, wants=25.275919252333562, using_ac=True
# Current zone temperatures in EP:
#   West Zone: 24.43711244105179
# cleaner_0: current_temp=21.39922323906939, wants=27.24913785097528, using_ac=True
# cleaner_1: current_temp=21.39922323906939, wants=27.69715369668513, using_ac=True
#   East Zone: 49.81537936826305
# cleaner_2: current_temp=21.39922323906939, wants=27.363008467340865, using_ac=True
# cleaner_3: current_temp=21.39922323906939, wants=27.88613437280151, using_ac=True
# cleaner_4: current_temp=20.33514954689939, wants=27.774420392923584, using_ac=True
# warden_0: current_temp=20.33514954689939, wants=26.619725591690457, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
# warden_1: current_temp=21.39922323906939, wants=25.0066133093452, using_ac=True
#   West Zone: 24.412999922680218
# visitor_0: current_temp=20.33514954689939, wants=24.249268117344005, using_ac=True
# visitor_1: current_temp=20.33514954689939, wants=24.359206341372037, using_ac=True
#   East Zone: 50.05978250485382
# visitor_2: current_temp=21.39922323906939, wants=24.02663712975208, using_ac=True
# visitor_3: current_temp=21.39922323906939, wants=25.314272454215118, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# visitor_4: current_temp=20.33514954689939, wants=24.03119252642477, using_ac=True
# visitor_5: current_temp=21.39922323906939, wants=25.659053595698662, using_ac=True
# Current zone temperatures in EP:
# visitor_6: current_temp=21.39922323906939, wants=25.181083868355653, using_ac=True
#   West Zone: 24.40835960505122
# visitor_7: current_temp=21.39922323906939, wants=24.73330685774162, using_ac=True
#   East Zone: 50.53989845563205
# visitor_8: current_temp=21.39922323906939, wants=24.401414514438766, using_ac=True
# visitor_9: current_temp=21.39922323906939, wants=25.672447656316677, using_ac=True
# visitor_10: current_temp=20.33514954689939, wants=24.917866901328225, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# visitor_11: current_temp=20.33514954689939, wants=24.96635696585956, using_ac=True
# Current zone temperatures in EP:
# visitor_12: current_temp=21.39922323906939, wants=24.86885891391655, using_ac=True
#   West Zone: 24.421188254691284
# visitor_13: current_temp=20.33514954689939, wants=24.391652805428798, using_ac=True
# visitor_14: current_temp=21.39922323906939, wants=24.968375078730734, using_ac=True
#   East Zone: 50.12890262296247
# visitor_15: current_temp=21.39922323906939, wants=25.09521667227684, using_ac=True
# visitor_16: current_temp=21.39922323906939, wants=24.019622798236405, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# visitor_17: current_temp=20.33514954689939, wants=24.58388467486708, using_ac=True
# visitor_18: current_temp=20.33514954689939, wants=24.239016345168007, using_ac=True
# Current zone temperatures in EP:
# visitor_19: current_temp=20.33514954689939, wants=24.21310866824882, using_ac=True
#   West Zone: 24.40810657202849
# policy_0: current_temp=20.33514954689939, wants=25, using_ac=True
#   East Zone: 50.340797099543394
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 24.403843497012915
#   East Zone: 50.48081282103537
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 24.402290135403636
#   East Zone: 50.6784586650017
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 24.401989950731092
#   East Zone: 50.97926666672349
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 24.405131087443312
#   East Zone: 50.775163016141875
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 24.40333708975468
#   East Zone: 50.42945800401418
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
#   West Zone: 24.402659342491052
#   East Zone: 50.51934324740973
# Applied setpoints to EP:
#   West Zone: 24.01 °C
#   East Zone: 24.02 °C
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_0: current_temp=22.996341768736546, wants=24.675240423840595, using_ac=False
# Current zone temperatures in EP:
# student_1: current_temp=22.997740002168275, wants=25.858929169130345, using_ac=True
# student_2: current_temp=22.996341768736546, wants=24.413816872458025, using_ac=False
#   West Zone: 24.40287226513881
#   East Zone: 50.3610532352205
# student_3: current_temp=22.997740002168275, wants=24.735525892064874, using_ac=True
# student_4: current_temp=22.997740002168275, wants=24.952141524063997, using_ac=False
# student_5: current_temp=22.997740002168275, wants=24.617357321504233, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_6: current_temp=22.996341768736546, wants=25.670119139586646, using_ac=True
# student_7: current_temp=22.997740002168275, wants=24.01790091811912, using_ac=False
# Current zone temperatures in EP:
# student_8: current_temp=22.996341768736546, wants=24.07530597762634, using_ac=False
#   West Zone: 24.402202712903833
#   East Zone: 50.405666606421995
# student_9: current_temp=22.996341768736546, wants=24.095973720210257, using_ac=False
# student_10: current_temp=22.997740002168275, wants=25.53965501264419, using_ac=True
# student_11: current_temp=22.997740002168275, wants=25.616388794601523, using_ac=True
# student_12: current_temp=22.996341768736546, wants=25.66849558644953, using_ac=TrueZone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
#
# Current zone temperatures in EP:
#   West Zone: 24.45945377016013
# student_13: current_temp=22.997740002168275, wants=24.031225836254226, using_ac=False
# student_14: current_temp=22.997740002168275, wants=25.09637354045358, using_ac=True
#   East Zone: 50.25173741003981
# student_15: current_temp=22.996341768736546, wants=25.31861401359614, using_ac=True
# student_16: current_temp=22.997740002168275, wants=25.304138998971148, using_ac=True
# Zone temp handles:student_17: current_temp=22.996341768736546, wants=24.59862081577627, using_ac=False
#  {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_18: current_temp=22.996341768736546, wants=25.930887908384154, using_ac=True
# student_19: current_temp=22.997740002168275, wants=25.142757419205235, using_ac=False
# Current zone temperatures in EP:
# student_20: current_temp=22.996341768736546, wants=25.73104887698365, using_ac=True
#   West Zone: 24.42251291932947
#   East Zone: 50.393576177383245
# student_21: current_temp=22.997740002168275, wants=25.525578459697634, using_ac=True
# student_22: current_temp=22.997740002168275, wants=25.93841346869749, using_ac=True
# student_23: current_temp=22.996341768736546, wants=24.150402060556274, using_ac=False
# student_24: current_temp=22.997740002168275, wants=25.7133169721554, using_ac=True
# student_25: current_temp=22.996341768736546, wants=24.08356296836369, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
# student_26: current_temp=22.997740002168275, wants=25.71790006107961, using_ac=True
# student_27: current_temp=22.996341768736546, wants=25.29973726369989, using_ac=False
#   West Zone: 24.352400610731383
# student_28: current_temp=22.996341768736546, wants=25.320341714726393, using_ac=True
#   East Zone: 50.253919911906465
# student_29: current_temp=22.997740002168275, wants=25.395950822014726, using_ac=True
# student_30: current_temp=22.996341768736546, wants=24.010069677661022, using_ac=False
# student_31: current_temp=22.997740002168275, wants=24.330557206510434, using_ac=False
# student_32: current_temp=22.997740002168275, wants=24.044175332068328, using_ac=False
# student_33: current_temp=22.997740002168275, wants=25.185805046438368, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_34: current_temp=22.996341768736546, wants=24.792734658096002, using_ac=False
# student_35: current_temp=22.997740002168275, wants=24.12056442608282, using_ac=False
# Current zone temperatures in EP:
#   West Zone: 24.262091651096327
#   East Zone: 50.24647654749399
# student_36: current_temp=22.997740002168275, wants=24.67487502913001, using_ac=False
# student_37: current_temp=22.996341768736546, wants=25.838426161570183, using_ac=True
# student_38: current_temp=22.997740002168275, wants=24.738612438246435, using_ac=False
# student_39: current_temp=22.996341768736546, wants=25.138477774114477, using_ac=False
# student_40: current_temp=22.996341768736546, wants=24.56316143565178, using_ac=False
# student_41: current_temp=22.996341768736546, wants=25.274085019728115, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_42: current_temp=22.997740002168275, wants=25.299339943223057, using_ac=False
# Current zone temperatures in EP:
#   West Zone: 24.264307959998185
# student_43: current_temp=22.996341768736546, wants=25.70075881254443, using_ac=True
#   East Zone: 50.21604320446576
# student_44: current_temp=22.996341768736546, wants=25.383046075684923, using_ac=True
# student_45: current_temp=22.997740002168275, wants=24.358484458304993, using_ac=False
# student_46: current_temp=22.997740002168275, wants=25.72634461684155, using_ac=True
# student_47: current_temp=22.997740002168275, wants=25.093274849662848, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_48: current_temp=22.997740002168275, wants=24.149846586813176, using_ac=False
# Current zone temperatures in EP:
# student_49: current_temp=22.996341768736546, wants=25.58430520108372, using_ac=True
#   West Zone: 24.283369784877937
# staff_0: current_temp=22.997740002168275, wants=26.60661847659038, using_ac=True
#   East Zone: 50.17325102995619
# staff_1: current_temp=22.996341768736546, wants=26.645490031816188, using_ac=True
# staff_2: current_temp=22.997740002168275, wants=26.75848176823084, using_ac=True
# staff_3: current_temp=22.997740002168275, wants=25.517438461166538, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# staff_4: current_temp=22.997740002168275, wants=26.500497257272873, using_ac=True
# Current zone temperatures in EP:
# staff_5: current_temp=22.996341768736546, wants=25.77593567044644, using_ac=True
#   West Zone: 24.29382389008838
# staff_6: current_temp=22.997740002168275, wants=25.425027965873138, using_ac=True
#   East Zone: 50.08824020802612
# staff_7: current_temp=22.996341768736546, wants=26.469932585323726, using_ac=True
# staff_8: current_temp=22.996341768736546, wants=25.090242248851805, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# staff_9: current_temp=22.997740002168275, wants=25.275919252333562, using_ac=True
# cleaner_0: current_temp=22.996341768736546, wants=27.24913785097528, using_ac=True
# Current zone temperatures in EP:
#   West Zone: 24.32810101041742
# cleaner_1: current_temp=22.996341768736546, wants=27.69715369668513, using_ac=True
#   East Zone: 50.13856220914684
# cleaner_2: current_temp=22.996341768736546, wants=27.363008467340865, using_ac=True
# cleaner_3: current_temp=22.996341768736546, wants=27.88613437280151, using_ac=True
# cleaner_4: current_temp=22.997740002168275, wants=27.774420392923584, using_ac=True
# warden_0: current_temp=22.997740002168275, wants=26.619725591690457, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# warden_1: current_temp=22.996341768736546, wants=25.0066133093452, using_ac=False
# Current zone temperatures in EP:
#   West Zone: 24.279804575177742
# visitor_0: current_temp=22.997740002168275, wants=24.249268117344005, using_ac=False
#   East Zone: 50.06797739741534
# visitor_1: current_temp=22.997740002168275, wants=24.359206341372037, using_ac=True
# visitor_2: current_temp=22.996341768736546, wants=24.02663712975208, using_ac=False
# visitor_3: current_temp=22.996341768736546, wants=25.314272454215118, using_ac=True
# visitor_4: current_temp=22.997740002168275, wants=24.03119252642477, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# visitor_5: current_temp=22.996341768736546, wants=25.659053595698662, using_ac=True
# visitor_6: current_temp=22.996341768736546, wants=25.181083868355653, using_ac=True
# Current zone temperatures in EP:
#   West Zone: 24.219060162729114
# visitor_7: current_temp=22.996341768736546, wants=24.73330685774162, using_ac=True
#   East Zone: 50.016415881643326
# visitor_8: current_temp=22.996341768736546, wants=24.401414514438766, using_ac=True
# visitor_9: current_temp=22.996341768736546, wants=25.672447656316677, using_ac=True
# visitor_10: current_temp=22.997740002168275, wants=24.917866901328225, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# visitor_11: current_temp=22.997740002168275, wants=24.96635696585956, using_ac=True
# Current zone temperatures in EP:
# visitor_12: current_temp=22.996341768736546, wants=24.86885891391655, using_ac=True
# visitor_13: current_temp=22.997740002168275, wants=24.391652805428798, using_ac=True
#   West Zone: 24.200577047329215
#   East Zone: 50.030993940795724
# visitor_14: current_temp=22.996341768736546, wants=24.968375078730734, using_ac=True
# visitor_15: current_temp=22.996341768736546, wants=25.09521667227684, using_ac=True
# visitor_16: current_temp=22.996341768736546, wants=24.019622798236405, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# visitor_17: current_temp=22.997740002168275, wants=24.58388467486708, using_ac=True
# Current zone temperatures in EP:
# visitor_18: current_temp=22.997740002168275, wants=24.239016345168007, using_ac=True
# visitor_19: current_temp=22.997740002168275, wants=24.21310866824882, using_ac=False
#   West Zone: 24.235596313833746
# policy_0: current_temp=22.997740002168275, wants=25, using_ac=True
#   East Zone: 49.98066023340887
# Applied setpoints to EP:
#   West Zone: 24.40 °C
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
#   East Zone: 24.24 °C
# student_0: current_temp=22.992167344417737, wants=24.675240423840595, using_ac=False
# Current zone temperatures in EP:
#   West Zone: 24.285220023618887
#   East Zone: 49.91772610530475
# student_1: current_temp=23.136611531109388, wants=25.858929169130345, using_ac=True
# student_2: current_temp=22.992167344417737, wants=24.413816872458025, using_ac=False
# student_3: current_temp=23.136611531109388, wants=24.735525892064874, using_ac=False
# student_4: current_temp=23.136611531109388, wants=24.952141524063997, using_ac=False
# student_5: current_temp=23.136611531109388, wants=24.617357321504233, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_6: current_temp=22.992167344417737, wants=25.670119139586646, using_ac=True
# Current zone temperatures in EP:
#   West Zone: 24.31102032995341
# student_7: current_temp=23.136611531109388, wants=24.01790091811912, using_ac=False
#   East Zone: 49.94498767423879
# student_8: current_temp=22.992167344417737, wants=24.07530597762634, using_ac=False
# student_9: current_temp=22.992167344417737, wants=24.095973720210257, using_ac=False
# student_10: current_temp=23.136611531109388, wants=25.53965501264419, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
# student_11: current_temp=23.136611531109388, wants=25.616388794601523, using_ac=True
#   West Zone: 24.26389846266416
# student_12: current_temp=22.992167344417737, wants=25.66849558644953, using_ac=True
#   East Zone: 49.89429652079723
# student_13: current_temp=23.136611531109388, wants=24.031225836254226, using_ac=False
# student_14: current_temp=23.136611531109388, wants=25.09637354045358, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_15: current_temp=22.992167344417737, wants=25.31861401359614, using_ac=True
# student_16: current_temp=23.136611531109388, wants=25.304138998971148, using_ac=True
# Current zone temperatures in EP:
# ...
# visitor_16: current_temp=22.974820143495275, wants=24.019622798236405, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# visitor_17: current_temp=24.182690723823566, wants=24.58388467486708, using_ac=False
# Current zone temperatures in EP:
# visitor_18: current_temp=24.182690723823566, wants=24.239016345168007, using_ac=False
#   West Zone: 24.660973834048185
# visitor_19: current_temp=24.182690723823566, wants=24.21310866824882, using_ac=False
#   East Zone: 46.1477453520808
# policy_0: current_temp=24.182690723823566, wants=25, using_ac=False
# Applied setpoints to EP:
#   West Zone: 24.40 °C
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
#   East Zone: 25.86 °C
# Current zone temperatures in EP:
#   West Zone: 24.738055677741148
# student_0: current_temp=33.43570812885471, wants=24.675240423840595, using_ac=True
# student_1: current_temp=27.661609914253763, wants=25.858929169130345, using_ac=True
#   East Zone: 46.08960990520897
# student_2: current_temp=33.43570812885471, wants=24.413816872458025, using_ac=True
# student_3: current_temp=27.661609914253763, wants=24.735525892064874, using_ac=True
# student_4: current_temp=27.661609914253763, wants=24.952141524063997, using_ac=True
# student_5: current_temp=27.661609914253763, wants=24.617357321504233, using_ac=True
# student_6: current_temp=33.43570812885471, wants=25.670119139586646, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_7: current_temp=27.661609914253763, wants=24.01790091811912, using_ac=True
# Current zone temperatures in EP:
# student_8: current_temp=33.43570812885471, wants=24.07530597762634, using_ac=True
#   West Zone: 24.804084549608397
#   East Zone: 46.171005067836056
# student_9: current_temp=33.43570812885471, wants=24.095973720210257, using_ac=True
# student_10: current_temp=27.661609914253763, wants=25.53965501264419, using_ac=False
# student_11: current_temp=27.661609914253763, wants=25.616388794601523, using_ac=True
# student_12: current_temp=33.43570812885471, wants=25.66849558644953, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_13: current_temp=27.661609914253763, wants=24.031225836254226, using_ac=True
# Current zone temperatures in EP:
#   West Zone: 24.87532535985222
# student_14: current_temp=27.661609914253763, wants=25.09637354045358, using_ac=True
# student_15: current_temp=33.43570812885471, wants=25.31861401359614, using_ac=True
#   East Zone: 45.97304131645772
# student_16: current_temp=27.661609914253763, wants=25.304138998971148, using_ac=True
# student_17: current_temp=33.43570812885471, wants=24.59862081577627, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# Current zone temperatures in EP:
# student_18: current_temp=33.43570812885471, wants=25.930887908384154, using_ac=True
#   West Zone: 24.94018658194281
# student_19: current_temp=27.661609914253763, wants=25.142757419205235, using_ac=True
# student_20: current_temp=33.43570812885471, wants=25.73104887698365, using_ac=True
#   East Zone: 45.9378502401461
# student_21: current_temp=27.661609914253763, wants=25.525578459697634, using_ac=False
# student_22: current_temp=27.661609914253763, wants=25.93841346869749, using_ac=False
# student_23: current_temp=33.43570812885471, wants=24.150402060556274, using_ac=True
# student_24: current_temp=27.661609914253763, wants=25.7133169721554, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_25: current_temp=33.43570812885471, wants=24.08356296836369, using_ac=True
# Current zone temperatures in EP:
#   West Zone: 24.9741196555308
# student_26: current_temp=27.661609914253763, wants=25.71790006107961, using_ac=True
#   East Zone: 45.83936373669353
# student_27: current_temp=33.43570812885471, wants=25.29973726369989, using_ac=True
# student_28: current_temp=33.43570812885471, wants=25.320341714726393, using_ac=True
# student_29: current_temp=27.661609914253763, wants=25.395950822014726, using_ac=False
# student_30: current_temp=33.43570812885471, wants=24.010069677661022, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_31: current_temp=27.661609914253763, wants=24.330557206510434, using_ac=True
# student_32: current_temp=27.661609914253763, wants=24.044175332068328, using_ac=True
# Current zone temperatures in EP:
# student_33: current_temp=27.661609914253763, wants=25.185805046438368, using_ac=True
#   West Zone: 24.99226927388657
# student_34: current_temp=33.43570812885471, wants=24.792734658096002, using_ac=True
#   East Zone: 45.75605853739381
# student_35: current_temp=27.661609914253763, wants=24.12056442608282, using_ac=True
# student_36: current_temp=27.661609914253763, wants=24.67487502913001, using_ac=True
# student_37: current_temp=33.43570812885471, wants=25.838426161570183, using_ac=True
# student_38: current_temp=27.661609914253763, wants=24.738612438246435, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_39: current_temp=33.43570812885471, wants=25.138477774114477, using_ac=True
# student_40: current_temp=33.43570812885471, wants=24.56316143565178, using_ac=True
# Current zone temperatures in EP:
#   West Zone: 25.015845299521526
# student_41: current_temp=33.43570812885471, wants=25.274085019728115, using_ac=True
# student_42: current_temp=27.661609914253763, wants=25.299339943223057, using_ac=False
#   East Zone: 45.681098737648234
# student_43: current_temp=33.43570812885471, wants=25.70075881254443, using_ac=True
# student_44: current_temp=33.43570812885471, wants=25.383046075684923, using_ac=True
# student_45: current_temp=27.661609914253763, wants=24.358484458304993, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_46: current_temp=27.661609914253763, wants=25.72634461684155, using_ac=False
# Current zone temperatures in EP:
# student_47: current_temp=27.661609914253763, wants=25.093274849662848, using_ac=True
# student_48: current_temp=27.661609914253763, wants=24.149846586813176, using_ac=True
#   West Zone: 25.033452440516687
#   East Zone: 45.60120960644423
# student_49: current_temp=33.43570812885471, wants=25.58430520108372, using_ac=True
# staff_0: current_temp=27.661609914253763, wants=26.60661847659038, using_ac=False
# staff_1: current_temp=33.43570812885471, wants=26.645490031816188, using_ac=True
# staff_2: current_temp=27.661609914253763, wants=26.75848176823084, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# staff_3: current_temp=27.661609914253763, wants=25.517438461166538, using_ac=True
# staff_4: current_temp=27.661609914253763, wants=26.500497257272873, using_ac=False
# Current zone temperatures in EP:
# staff_5: current_temp=33.43570812885471, wants=25.77593567044644, using_ac=True
#   West Zone: 25.039060413009086
# staff_6: current_temp=27.661609914253763, wants=25.425027965873138, using_ac=True
#   East Zone: 45.52884496595555
# staff_7: current_temp=33.43570812885471, wants=26.469932585323726, using_ac=True
# staff_8: current_temp=33.43570812885471, wants=25.090242248851805, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# staff_9: current_temp=27.661609914253763, wants=25.275919252333562, using_ac=True
# Current zone temperatures in EP:
# cleaner_0: current_temp=33.43570812885471, wants=27.24913785097528, using_ac=True
#   West Zone: 25.045175607191766
# cleaner_1: current_temp=33.43570812885471, wants=27.69715369668513, using_ac=True
#   East Zone: 45.45694000006771
# cleaner_2: current_temp=33.43570812885471, wants=27.363008467340865, using_ac=True
# cleaner_3: current_temp=33.43570812885471, wants=27.88613437280151, using_ac=True
# cleaner_4: current_temp=27.661609914253763, wants=27.774420392923584, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# warden_0: current_temp=27.661609914253763, wants=26.619725591690457, using_ac=False
# warden_1: current_temp=33.43570812885471, wants=25.0066133093452, using_ac=True
# Current zone temperatures in EP:
# visitor_0: current_temp=27.661609914253763, wants=24.249268117344005, using_ac=True
# visitor_1: current_temp=27.661609914253763, wants=24.359206341372037, using_ac=True
#   West Zone: 25.053557670989356
#   East Zone: 45.38785125788483
# visitor_2: current_temp=33.43570812885471, wants=24.02663712975208, using_ac=True
# visitor_3: current_temp=33.43570812885471, wants=25.314272454215118, using_ac=True
# visitor_4: current_temp=27.661609914253763, wants=24.03119252642477, using_ac=True
# visitor_5: current_temp=33.43570812885471, wants=25.659053595698662, using_ac=True
# visitor_6: current_temp=33.43570812885471, wants=25.181083868355653, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# visitor_7: current_temp=33.43570812885471, wants=24.73330685774162, using_ac=True
# Current zone temperatures in EP:
# visitor_8: current_temp=33.43570812885471, wants=24.401414514438766, using_ac=True
#   West Zone: 25.05660404998641
# visitor_9: current_temp=33.43570812885471, wants=25.672447656316677, using_ac=True
# visitor_10: current_temp=27.661609914253763, wants=24.917866901328225, using_ac=True
#   East Zone: 45.321192556732065
# visitor_11: current_temp=27.661609914253763, wants=24.96635696585956, using_ac=True
# visitor_12: current_temp=33.43570812885471, wants=24.86885891391655, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# visitor_13: current_temp=27.661609914253763, wants=24.391652805428798, using_ac=True
# visitor_14: current_temp=33.43570812885471, wants=24.968375078730734, using_ac=True
# Current zone temperatures in EP:
# visitor_15: current_temp=33.43570812885471, wants=25.09521667227684, using_ac=True
#   West Zone: 25.056351474700126
#   East Zone: 45.25649868773345
# visitor_16: current_temp=33.43570812885471, wants=24.019622798236405, using_ac=True
# visitor_17: current_temp=27.661609914253763, wants=24.58388467486708, using_ac=True
# visitor_18: current_temp=27.661609914253763, wants=24.239016345168007, using_ac=True
# visitor_19: current_temp=27.661609914253763, wants=24.21310866824882, using_ac=True
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# policy_0: current_temp=27.661609914253763, wants=25, using_ac=True
# Current zone temperatures in EP:
# Applied setpoints to EP:
#   West Zone: 24.01 °C
#   West Zone: 25.058593402019472
#   East Zone: 24.02 °C
#   East Zone: 45.194175869222164
# student_0: current_temp=24.595657996039918, wants=24.675240423840595, using_ac=False
# student_1: current_temp=25.054563838277815, wants=25.858929169130345, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_2: current_temp=24.595657996039918, wants=24.413816872458025, using_ac=False
# student_3: current_temp=25.054563838277815, wants=24.735525892064874, using_ac=False
# Current zone temperatures in EP:
# student_4: current_temp=25.054563838277815, wants=24.952141524063997, using_ac=False
# student_5: current_temp=25.054563838277815, wants=24.617357321504233, using_ac=False
#   West Zone: 25.061113028317532
# student_6: current_temp=24.595657996039918, wants=25.670119139586646, using_ac=False
#   East Zone: 45.13412461742128
# student_7: current_temp=25.054563838277815, wants=24.01790091811912, using_ac=False
# student_8: current_temp=24.595657996039918, wants=24.07530597762634, using_ac=False
# student_9: current_temp=24.595657996039918, wants=24.095973720210257, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_10: current_temp=25.054563838277815, wants=25.53965501264419, using_ac=False
# Current zone temperatures in EP:
# student_11: current_temp=25.054563838277815, wants=25.616388794601523, using_ac=False
#   West Zone: 25.060486774494926
# student_12: current_temp=24.595657996039918, wants=25.66849558644953, using_ac=False
#   East Zone: 45.076000687213934
# student_13: current_temp=25.054563838277815, wants=24.031225836254226, using_ac=False
# student_14: current_temp=25.054563838277815, wants=25.09637354045358, using_ac=False
# student_15: current_temp=24.595657996039918, wants=25.31861401359614, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_16: current_temp=25.054563838277815, wants=25.304138998971148, using_ac=False
# Current zone temperatures in EP:
#   West Zone: 24.943895642355425
#   East Zone: 45.019886954223
# student_17: current_temp=24.595657996039918, wants=24.59862081577627, using_ac=False
# student_18: current_temp=24.595657996039918, wants=25.930887908384154, using_ac=False
# student_19: current_temp=25.054563838277815, wants=25.142757419205235, using_ac=False
# student_20: current_temp=24.595657996039918, wants=25.73104887698365, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_21: current_temp=25.054563838277815, wants=25.525578459697634, using_ac=False
# student_22: current_temp=25.054563838277815, wants=25.93841346869749, using_ac=False
# Current zone temperatures in EP:
# student_23: current_temp=24.595657996039918, wants=24.150402060556274, using_ac=False
#   West Zone: 24.82543135374065
# student_24: current_temp=25.054563838277815, wants=25.7133169721554, using_ac=False
#   East Zone: 44.96557416380498
# student_25: current_temp=24.595657996039918, wants=24.08356296836369, using_ac=False
# student_26: current_temp=25.054563838277815, wants=25.71790006107961, using_ac=False
# student_27: current_temp=24.595657996039918, wants=25.29973726369989, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_28: current_temp=24.595657996039918, wants=25.320341714726393, using_ac=False
# student_29: current_temp=25.054563838277815, wants=25.395950822014726, using_ac=False
# Current zone temperatures in EP:
# student_30: current_temp=24.595657996039918, wants=24.010069677661022, using_ac=False
#   West Zone: 24.83049615373804
#   East Zone: 44.91351550292711
# student_31: current_temp=25.054563838277815, wants=24.330557206510434, using_ac=False
# student_32: current_temp=25.054563838277815, wants=24.044175332068328, using_ac=False
# student_33: current_temp=25.054563838277815, wants=25.185805046438368, using_ac=False
# student_34: current_temp=24.595657996039918, wants=24.792734658096002, using_ac=False
# Zone temp handles: {'West Zone': 78, 'East Zone': 82}
# Zone setpoint handles: {'West Zone': 274, 'East Zone': 276}
# [Callback] Triggered
# student_35: current_temp=25.054563838277815, wants=24.12056442608282, using_ac=False
# Current zone temperatures in EP:
# student_36: current_temp=25.054563838277815, wants=24.67487502913001, using_ac=False
#   West Zone: 24.828655367739056
#   East Zone: 44.86293206710074
# student_37: current_temp=24.595657996039918, wants=25.838426161570183, using_ac=False
